# %%
from dsa.dijkstras import shortest_path, find_path
from dsa.graph import AdjacencyListWeightedGraph

graph = AdjacencyListWeightedGraph()
graph.add_edge('A', 'B', 1)
graph.add_edge('A', 'D', 4)
graph.add_edge('B', 'C', 5)
graph.add_edge('B', 'E', 3)
graph.add_edge('C', 'F', 6)
graph.add_edge('D', 'E', 7)
graph.add_edge('E', 'F', 2)

graph

# %%
"A" in graph
# Out:
# True

# %%
"X" in graph
# Out:
# False

# %%
weight_table, previous = shortest_path(graph, 'A', 'F', debug=True)
# Out:
# {'A': 0, 'B': 1}
# {'A': 0, 'B': 1, 'D': 4}
# {'A': 0, 'B': 1, 'D': 4, 'C': 6}
# {'A': 0, 'B': 1, 'D': 4, 'C': 6, 'E': 4}
# {'A': 0, 'B': 1, 'D': 4, 'C': 6, 'E': 4, 'F': 6}

# %%
previous
# Out:
# {'A': 'A', 'B': 'A', 'D': 'A', 'C': 'B', 'E': 'B', 'F': 'E'}

# %%
find_path(graph, 'A', 'F')
# Out:
# ['A', 'B', 'E', 'F']
